# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51087/ADM_2025/blob/main/ADM2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=np.random.randn(1000)
sns.histplot(data,bins=30,kde=True)
plt.title("Histogram with KDE")
plt.show()

# %%
df=pd.DataFrame({"x":np.random.rand(100),"y":np.random.rand(100)})
sns.scatterplot(x="x",y="y",data=df)
plt.title("Scatter Plot Example")
plt.show()

# %%
import matplotlib.pyplot as pl
import numpy as np
x=np.linspace(-np.pi,np.pi,256,endpoint=True)
y=np.cos(x)
y1=np.sin(x)
pl.plot(x,y)
pl.plot(x,y1)
pl.show()

# %%
data={
    "Age":np.random.randint(18,65,size=200),
    "Purchase Amount":np.random.normal(100,50,200).clip(10,300),
    "Category":np.random.choice(["Electronics","Clothing","Books"],200)
}
df=pd.DataFrame(data)
df.head()
# Out:
#    Age  Purchase Amount     Category
# 0   46        92.062813        Books
# 1   22        72.377342        Books
# 2   21        71.720876     Clothing
# 3   21        95.797399     Clothing
# 4   58        23.569787  Electronics
